# %% [markdown]
# <a href="https://colab.research.google.com/github/atlas-github/sample_parl/blob/master/Analyzing_Unstructured_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("sample_parl.csv")
df
# Out:
#                                               Speaker                                               Text
# 0   Dato' Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  minta Menteri Pelancongan, Seni dan Budaya men...
# 1   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  Bismillahi rahmani rahim, assalamualaikum wara...
# 2   Dato' Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  Saya mengucapkan jutaan terima kasih kepada Ya...
# 3   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  Tuan Yang di-Pertua. Untuk menjawab soalan tam...
# 4   Dato’ Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  Maksud saya mengenai pembangunan Yang Berhorma...
# 5   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  Yang Berhormat, kita memang ada rancangan untu...
# 6                                 Tuan Yang di-Pertua                                  Soalan tambahan.
# 7            Tuan Yusuf bin Abd Wahab [Tanjong Manis]                     Tanjong Manis, Tanjong Manis.
# 8                 Dato’ Jalaluddin bin Alias [Jelebu]                                           Jelebu.
# 9            Tuan Yusuf bin Abd Wahab [Tanjong Manis]  Tanjong Manis. Tuan Yang diPertua, Tanjong Man...
# 10                Dato’ Jalaluddin bin Alias [Jelebu]              Jelebu. Hutan lipur banyak di Jelebu.
# 11           Tuan Yusuf bin Abd Wahab [Tanjong Manis]  Tanjong Manis. Tuan Yang diPertua, Tanjong Man...
# 12                Dato’ Jalaluddin bin Alias [Jelebu]                  Hutan lipur ni banyak di Jelebu.
# 13                                Tuan Yang di-Pertua                                     Saya ingat...
# 14                Dato’ Jalaluddin bin Alias [Jelebu]  Terima kasih Tuan Yang di-Pertua. Dia kadang-k...
# 15                                Tuan Yang di-Pertua                    Silakan Yang Berhormat Jelebu.
# 16                Dato’ Jalaluddin bin Alias [Jelebu]   Saya hendak minta pihak kementerian berikan p...
# 17  Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  Terima kasih Tuan Yang di-Pertua, saya melihat...
# 18                                Tuan Yang di-Pertua  Cadangan yang baik. Tuan Yang di-Pertua pun me...
# 19                Dato’ Jalaluddin bin Alias [Jelebu]  Terima kasih Yang Berhormat Menteri, surat aka...
# 20    Tuan Abdul Latiff bin Abdul Rahman [Kuala Krai]  Tahniah Yang Berhormat Menteri, tahniah. Saya ...
# 21  Menteri Pelancongan, Seni dan Budaya [Datuk Mo...                                   Saya tak nak...
# 22          Dato’ Seri Dr. Shahidan bin Kassim [Arau]          Tahniah Yang Berhormat Menteri, tahniah.
# 23  Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  Saya tak nak Ahli-ahli Yang Berhormat ini rugi...
# 24    Tuan Abdul Latiff bin Abdul Rahman [Kuala Krai]            Ini baru betul Yang Berhormat Menteri.

# %%
# !pip install malaya
# Out:
# Requirement already satisfied: malaya in /usr/local/lib/python3.6/dist-packages (3.5.2)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.6/dist-packages (from malaya) (5.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from malaya) (1.18.4)
# Requirement already satisfied: albert-tensorflow in /usr/local/lib/python3.6/dist-packages (from malaya) (1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from malaya) (2.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.6/dist-packages (from malaya) (0.1.91)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from malaya) (1.4.1)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from malaya) (0.0)
# Requirement already satisfied: herpetologist in /usr/local/lib/python3.6/dist-packages (from malaya) (0.0.8)
# Requirement already satisfied: unidecode in /usr/local/lib/python3.6/dist-packages (from malaya) (1.1.1)
# Requirement already satisfied: youtokentome in /usr/local/lib/python3.6/dist-packages (from malaya) (1.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from malaya) (2.23.0)
# Requirement already satisfied: dateparser in /usr/local/lib/python3.6/dist-packages (from malaya) (0.7.4)
# Requirement already satisfied: tensorflow<2.0,>=1.14 in /usr/local/lib/python3.6/dist-packages (from malaya) (1.15.2)
# Requirement already satisfied: bert-tensorflow in /usr/local/lib/python3.6/dist-packages (from malaya) (1.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from malaya) (4.41.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from malaya) (0.22.2.post1)
# Requirement already satisfied: PySastrawi in /usr/local/lib/python3.6/dist-packages (from malaya) (1.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from ftfy->malaya) (0.1.9)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from albert-tensorflow->malaya) (1.12.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->malaya) (4.4.2)
# Requirement already satisfied: memoization in /usr/local/lib/python3.6/dist-packages (from herpetologist->malaya) (0.3.1)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from youtokentome->malaya) (7.1.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->malaya) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->malaya) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->malaya) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->malaya) (2.9)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.6/dist-packages (from dateparser->malaya) (1.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from dateparser->malaya) (2.8.1)
# Requirement already satisfied: regex!=2019.02.19 in /usr/local/lib/python3.6/dist-packages (from dateparser->malaya) (2019.12.20)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from dateparser->malaya) (2018.9)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (0.2.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (0.2.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (0.9.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.1.2)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.29.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (3.2.1)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.15.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (0.8.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (1.0.8)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (3.10.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow<2.0,>=1.14->malaya) (0.34.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->malaya) (0.15.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<2.0,>=1.14->malaya) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<2.0,>=1.14->malaya) (46.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<2.0,>=1.14->malaya) (3.2.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow<2.0,>=1.14->malaya) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow<2.0,>=1.14->malaya) (1.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.16.0,>=1.15.0->tensorflow<2.0,>=1.14->malaya) (3.1.0)

# %%
import malaya
malaya.emotion.label
# Out:
# ['anger', 'fear', 'happy', 'love', 'sadness', 'surprise']

# %%
model = malaya.emotion.multinomial()
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator ComplementNB from version 0.22.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 0.22.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 0.22.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
model.predict([df.iloc[2, 1]])
# Out:
# ['anger']

# %%
model.predict_proba([df.iloc[2, 1]])
# Out:
# [{'anger': 0.3168547733448728,
#   'fear': 0.14767448881320275,
#   'happy': 0.13088171980427257,
#   'love': 0.10666615839911558,
#   'sadness': 0.19795303520701094,
#   'surprise': 0.09996982443152384}]

# %%
emotions = pd.DataFrame(columns = ['anger', 'fear', 'happy', 'love', 'sadness', 'surprise'])

for i in range(len(df)):
  result = pd.DataFrame(model.predict_proba([df.iloc[i, 1]]))
  emotions = emotions.append(result, ignore_index = True)

# %%
emotions
# Out:
#        anger      fear     happy      love   sadness  surprise
# 0   0.231862  0.131138  0.134627  0.124979  0.244913  0.132481
# 1   0.238093  0.116695  0.217780  0.123474  0.171392  0.132567
# 2   0.316855  0.147674  0.130882  0.106666  0.197953  0.099970
# 3   0.252482  0.157898  0.148688  0.127589  0.187247  0.126097
# 4   0.306371  0.146608  0.142913  0.120837  0.148703  0.134568
# 5   0.299077  0.128777  0.144333  0.140170  0.149790  0.137852
# 6   0.170148  0.152893  0.132502  0.136038  0.271495  0.136924
# 7   0.143107  0.154008  0.201308  0.173618  0.134847  0.193112
# 8   0.145088  0.153908  0.189621  0.207773  0.141876  0.161734
# 9   0.141875  0.160858  0.211531  0.166270  0.125977  0.193489
# 10  0.160861  0.168901  0.181363  0.198132  0.126224  0.164519
# 11  0.145570  0.183614  0.198692  0.161121  0.117661  0.193341
# 12  0.172293  0.178224  0.173549  0.185138  0.125021  0.165774
# 13  0.169315  0.158862  0.170805  0.172175  0.151146  0.177697
# 14  0.137756  0.235235  0.142066  0.140625  0.192364  0.151954
# 15  0.323224  0.126676  0.140412  0.164801  0.109307  0.135579
# 16  0.281013  0.165374  0.115929  0.116823  0.187629  0.133233
# 17  0.203757  0.194426  0.128506  0.128786  0.203654  0.140871
# 18  0.321994  0.175013  0.121242  0.119978  0.126815  0.134959
# 19  0.246929  0.138569  0.170059  0.123651  0.178635  0.142158
# 20  0.217794  0.131846  0.235689  0.139696  0.118446  0.156530
# 21  0.175744  0.159766  0.175683  0.173685  0.152627  0.162494
# 22  0.210811  0.125986  0.254160  0.135436  0.121685  0.151923
# 23  0.289081  0.134548  0.114965  0.112425  0.229370  0.119611
# 24  0.282160  0.131944  0.178558  0.122175  0.130624  0.154539

# %%
result = pd.concat([df, emotions], axis = 1)
result
# Out:
#                                               Speaker  ...  surprise
# 0   Dato' Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  ...  0.132481
# 1   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.132567
# 2   Dato' Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  ...  0.099970
# 3   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.126097
# 4   Dato’ Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  ...  0.134568
# 5   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.137852
# 6                                 Tuan Yang di-Pertua  ...  0.136924
# 7            Tuan Yusuf bin Abd Wahab [Tanjong Manis]  ...  0.193112
# 8                 Dato’ Jalaluddin bin Alias [Jelebu]  ...  0.161734
# 9            Tuan Yusuf bin Abd Wahab [Tanjong Manis]  ...  0.193489
# 10                Dato’ Jalaluddin bin Alias [Jelebu]  ...  0.164519
# 11           Tuan Yusuf bin Abd Wahab [Tanjong Manis]  ...  0.193341
# 12                Dato’ Jalaluddin bin Alias [Jelebu]  ...  0.165774
# 13                                Tuan Yang di-Pertua  ...  0.177697
# 14                Dato’ Jalaluddin bin Alias [Jelebu]  ...  0.151954
# 15                                Tuan Yang di-Pertua  ...  0.135579
# 16                Dato’ Jalaluddin bin Alias [Jelebu]  ...  0.133233
# 17  Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.140871
# 18                                Tuan Yang di-Pertua  ...  0.134959
# 19                Dato’ Jalaluddin bin Alias [Jelebu]  ...  0.142158
# 20    Tuan Abdul Latiff bin Abdul Rahman [Kuala Krai]  ...  0.156530
# 21  Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.162494
# 22          Dato’ Seri Dr. Shahidan bin Kassim [Arau]  ...  0.151923
# 23  Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.119611
# 24    Tuan Abdul Latiff bin Abdul Rahman [Kuala Krai]  ...  0.154539
#
# [25 rows x 8 columns]

# %%
result.nlargest(5, ['anger'])
# Out:
#                                               Speaker  ...  surprise
# 15                                Tuan Yang di-Pertua  ...  0.135579
# 18                                Tuan Yang di-Pertua  ...  0.134959
# 2   Dato' Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  ...  0.099970
# 4   Dato’ Seri Haji Mukhriz Tun Dr. Mahathir [Jerlun]  ...  0.134568
# 5   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.137852
#
# [5 rows x 8 columns]

# %%
result.nlargest(5, ['happy'])
# Out:
#                                               Speaker  ...  surprise
# 22          Dato’ Seri Dr. Shahidan bin Kassim [Arau]  ...  0.151923
# 20    Tuan Abdul Latiff bin Abdul Rahman [Kuala Krai]  ...  0.156530
# 1   Menteri Pelancongan, Seni dan Budaya [Datuk Mo...  ...  0.132567
# 9            Tuan Yusuf bin Abd Wahab [Tanjong Manis]  ...  0.193489
# 7            Tuan Yusuf bin Abd Wahab [Tanjong Manis]  ...  0.193112
#
# [5 rows x 8 columns]
